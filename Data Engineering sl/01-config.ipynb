# %%
base_dir_data = spark.sql("describe external location `data-zone`").select("url").collect()[0][0]               # sbit-unmanaged-dev/data-zone/
base_dir_checkpoint = spark.sql("describe external location `checkpoint-zone`").select("url").collect()[0][0]   # sbit-unmanaged-dev/checkpoint-zone/

#checkpoint helps to avoid duplicates and pick up where you left off previously
